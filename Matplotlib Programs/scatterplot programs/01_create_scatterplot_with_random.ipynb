# %%
'''
@Author: Kanchan
@Date: 2022-01-05
@Last Modified by: Kanchan
@Last Modified time: 2022-01-05
@Title : Write a Python program to draw a scatter graph taking a random distribution in X and Y and
plotted against each other.
'''

import matplotlib.pyplot as plt
from pylab import randn

#The numpy.random.randn() function creates an array of specified shape and fills it with 
# random values as per standard normal distribution.
#The randn function generates arrays of random numbers whose elements are normally distributed with mean 0, variance , and standard deviation.
#normal distribution=It is the distribution that occurs when a normal random variable has a mean of zero and a standard deviation of one
x=randn(100)
y=randn(100)
#print(x)
#print(y)
plt.scatter(x,y,color='g')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
# Out:
# [-1.2833259  -0.73782087 -0.55187061  1.10784913 -0.3911964  -1.43141237
#  -0.50315724  0.27089087  0.964455   -1.86618359  1.38570862 -1.26507859
#  -2.45296441 -0.79515482  0.76415131  1.93965188 -1.73776171  0.17374076
#  -0.15120923  1.67197527 -0.73414783  1.16994018 -0.93954404  0.29656868
#  -2.72023613 -1.52647732  1.50419328 -0.84515888 -0.05873761  1.04647749
#  -0.87272284 -2.83387541  1.92080826 -1.05795179 -0.93745667  0.34610399
#   1.06452374  0.48092754  1.07257292 -1.01570616  0.2027453   0.37970288
#  -0.13065696 -0.04338564 -0.76457245 -0.83467839 -0.40708014  1.6450897
#   0.10336032 -0.3657063  -0.11349605  0.3695139   1.26518193  0.1003155
#  -0.27902685 -0.42353895 -0.95759112 -0.89480389  0.85898597 -0.56048866
#  -0.66979056  2.13900819  1.04864783 -0.64322938  0.05784285  1.06286568
#   0.52250199 -1.02375313 -2.85701353 -0.73075528 -0.52432114  0.49666597
#  -0.87704744  1.57685155  0.15784698  2.76362751 -1.72368946 -1.32716161
#  -0.74308301 -0.02696191 -0.05830706  0.32416161  1.5943148  -0.67116201
#  -0.65199806 -1.45759952  1.14264892  0.12119278 -0.52566554 -0.70810215
#  -0.11762482  0.86827311  0.23014051  0.04914298  1.72989163  1.14360483
#  -1.8747429   1.19170945 -1.271945    0.12921068]
